# %% [markdown]
# # straddle分析 自然日版本

# %%
import sys
from tqdm import tqdm
import pandas as pd
import os
import datetime
import OptionTools

import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
from scipy.stats import norm

# %%
def delta_OLS(df, add=False):
    df = df.dropna()
    MON = df['weekday'].apply(lambda x: 1 if x == 0 else 0).to_numpy()
    TUE = df['weekday'].apply(lambda x: 1 if x == 1 else 0).to_numpy()
    WED = df['weekday'].apply(lambda x: 1 if x == 2 else 0).to_numpy()
    THU = df['weekday'].apply(lambda x: 1 if x == 3 else 0).to_numpy()
    FRI = df['weekday'].apply(lambda x: 1 if x == 4 else 0).to_numpy()
    y = df.neutral_pnl.values
    X = np.column_stack([MON, TUE, WED, THU, FRI])
    if add:
        X = sm.add_constant(X)
    model = sm.OLS(y, X)
    model = model.fit()
    for j, k in enumerate(model.params):
        print(round(k, 4))
        print("({})".format(round(model.tvalues[j], 2)))


#     print(round(model.f_pvalue, 4))
    print(round(model.rsquared_adj, 4))
    print(model.summary())
    return model

# %%
straddles = pd.read_csv('all_straddles_cd.csv')
straddles = straddles[straddles['date'] >= '2016-11-01']
straddles = straddles[straddles['dtm'] >= 8]
# straddles = straddles.drop_duplicates(subset='date').reset_index(drop=True)
straddles['principal'] = straddles['call_close'] / straddles[
    'call_delta'] - straddles['put_close'] / straddles['put_delta']

close_to_close = straddles[[
    'date', 'exe_date', 'weekday', 'dtm', 'call_delta', 'call_close',
    'call_next_close', 'put_delta', 'put_close', 'put_next_close', 'principal'
]]
close_to_open = straddles[[
    'date', 'exe_date', 'weekday', 'dtm', 'call_delta', 'call_close',
    'call_next_open', 'put_delta', 'put_close', 'put_next_open', 'principal'
]]
open_to_close = straddles[[
    'date', 'exe_date', 'weekday', 'dtm', 'call_delta', 'call_next_close',
    'call_next_open', 'put_delta', 'put_next_close', 'put_next_open',
    'principal'
]]

close_to_close['call_ret'] = close_to_close[
    'call_next_close'].values - close_to_close['call_close'].values
close_to_open['call_ret'] = close_to_open[
    'call_next_open'].values - close_to_open['call_close'].values
open_to_close['call_ret'] = open_to_close[
    'call_next_close'].values - open_to_close['call_next_open'].values

close_to_close['put_ret'] = close_to_close[
    'put_next_close'].values - close_to_close['put_close'].values
close_to_open['put_ret'] = close_to_open[
    'put_next_open'].values - close_to_open['put_close'].values
open_to_close['put_ret'] = open_to_close[
    'put_next_close'].values - open_to_close['put_next_open'].values

close_to_close['ret'] = close_to_close['call_ret'] / close_to_close[
    'call_delta'] - close_to_close['put_ret'] / close_to_close['put_delta']
close_to_open['ret'] = close_to_open['call_ret'] / close_to_open[
    'call_delta'] - close_to_open['put_ret'] / close_to_open['put_delta']
open_to_close['ret'] = open_to_close['call_ret'] / open_to_close[
    'call_delta'] - open_to_close['put_ret'] / open_to_close['put_delta']

close_to_close[
    'neutral_pnl'] = close_to_close['ret'] / close_to_close['principal']
close_to_open[
    'neutral_pnl'] = close_to_open['ret'] / close_to_close['principal']
open_to_close[
    'neutral_pnl'] = open_to_close['ret'] / close_to_close['principal']

# close_to_close['neutral_pnl'] = close_to_close['ret']
# close_to_open['neutral_pnl'] = close_to_open['ret']
# open_to_close['neutral_pnl'] = open_to_close['ret']

close_to_close['weekday'] = close_to_close.weekday.apply(lambda x:
                                                         (x + 1) % 5).values
close_to_open['weekday'] = close_to_open.weekday.apply(lambda x:
                                                       (x + 1) % 5).values
open_to_close['weekday'] = open_to_close.weekday.apply(lambda x:
                                                       (x + 1) % 5).values

delta_OLS(close_to_close)
delta_OLS(close_to_open)
delta_OLS(open_to_close)
# Out:
# -0.0014
# (-0.52)
# -0.0095
# (-3.37)
# -0.001
# (-0.36)
# -0.0021
# (-0.77)
# 0.0083
# (3.03)
# 0.0042
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.207
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           0.000350
# Time:                        22:20:06   Log-Likelihood:                 4507.8
# No. Observations:                3989   AIC:                            -9006.
# Df Residuals:                    3984   BIC:                            -8974.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0014      0.003     -0.520      0.603      -0.007       0.004
# x2            -0.0095      0.003     -3.372      0.001      -0.015      -0.004
# x3            -0.0010      0.003     -0.361      0.718      -0.006       0.004
# x4            -0.0021      0.003     -0.773      0.440      -0.008       0.003
# x5             0.0083      0.003      3.033      0.002       0.003       0.014
# ==============================================================================
# Omnibus:                     4994.604   Durbin-Watson:                   0.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1567169.915
# Skew:                           6.487   Prob(JB):                         0.00
# Kurtosis:                      99.232   Cond. No.                         1.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0008
# (-0.86)
# -0.0012
# (-1.27)
# 0.0018
# (1.97)
# -0.0014
# (-1.56)
# 0.0034
# (3.71)
# 0.0044
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.396
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           0.000248
# Time:                        22:20:06   Log-Likelihood:                 8838.4
# No. Observations:                3989   AIC:                        -1.767e+04
# Df Residuals:                    3984   BIC:                        -1.764e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0008      0.001     -0.860      0.390      -0.003       0.001
# x2            -0.0012      0.001     -1.272      0.203      -0.003       0.001
# x3             0.0018      0.001      1.971      0.049    1.02e-05       0.004
# x4            -0.0014      0.001     -1.555      0.120      -0.003       0.000
# x5             0.0034      0.001      3.709      0.000       0.002       0.005
# ==============================================================================
# Omnibus:                     6055.666   Durbin-Watson:                   1.637
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7723605.972
# Skew:                           8.900   Prob(JB):                         0.00
# Kurtosis:                     217.832   Cond. No.                         1.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0006
# (-0.25)
# -0.0083
# (-3.15)
# -0.0028
# (-1.1)
# -0.0007
# (-0.27)
# 0.0049
# (1.91)
# 0.0023
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.341
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):            0.00971
# Time:                        22:20:06   Log-Likelihood:                 4784.5
# No. Observations:                3989   AIC:                            -9559.
# Df Residuals:                    3984   BIC:                            -9528.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0006      0.003     -0.246      0.806      -0.006       0.004
# x2            -0.0083      0.003     -3.154      0.002      -0.013      -0.003
# x3            -0.0028      0.003     -1.100      0.271      -0.008       0.002
# x4            -0.0007      0.003     -0.265      0.791      -0.006       0.004
# x5             0.0049      0.003      1.908      0.056      -0.000       0.010
# ==============================================================================
# Omnibus:                     4676.777   Durbin-Watson:                   0.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1248060.794
# Skew:                           5.772   Prob(JB):                         0.00
# Kurtosis:                      88.882   Cond. No.                         1.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 获取realized vol

# %%
etfs = pd.read_csv('50etf_5m.csv')
etfs['time'] = etfs.date.apply(lambda x: x.split()[-1])
etfs['date'] = etfs.date.apply(lambda x: x.split()[0])
etfs = etfs[(etfs['date'] >= '2015-02-09') & (etfs['date'] <= '2021-04-14')]
etfs = etfs.reset_index(drop=True)

opens = etfs.groupby('date').apply(lambda x: x['open'].iloc[0]).reset_index()
opens['yclose'] = etfs.groupby('date').apply(
    lambda x: x['yclose'].iloc[0]).values
opens.columns = ['date', 'sectional_close', 'yclose']
opens['time'] = "09:30:00"

selected = etfs[['date', 'sectional_close', 'yclose', 'time']][:]
selected.loc[selected['time'] == '09:35:00',
             'yclose'] = opens['sectional_close'].values
selected = pd.concat(
    [selected, opens]).sort_values(by=['date', 'time']).reset_index(drop=True)
selected.loc[:, 'cont_change'] = np.log(selected['sectional_close'].values /
                                        selected['yclose'].values)

rvs = selected.groupby('date').apply(lambda x: np.sqrt(
    (x['cont_change']**2).sum()) * np.sqrt(252)).reset_index()
rvs.columns = ['date', 'rv']
overn = selected[selected['time'] == "09:30:00"].reset_index(drop=True)
overn['on_rv'] = np.abs(overn['cont_change']) * np.sqrt(252)
overn = overn[['date', 'on_rv']]
cm = selected[selected['time'] > "09:30:00"].groupby('date').apply(
    lambda x: np.sqrt(
        (x['cont_change']**2).sum()) * np.sqrt(252)).reset_index()
cm.columns = ['date', 'id_rv']

rvs = pd.merge(rvs, overn, on='date')
rvs = pd.merge(rvs, cm, on='date')

# %%
# straddle_rv = pd.merge(close_to_close[['date', 'dtm', 'weekday', 'ret', 'neutral_pnl']], rvs[['date', 'rv']])
rvs['rvc'] = rvs.rv - rvs.rv.shift(1)
rvs['pct_rvc'] = rvs.rv / rvs.rv.shift(1) - 1
rvs['rvc_id'] = rvs.id_rv - rvs.id_rv.shift(1)
rvs['rvc_on'] = rvs.on_rv - rvs.on_rv.shift(1)
rvs['abs_rvc'] = np.abs(rvs['pct_rvc'].values)
straddle_rv = pd.merge(
    close_to_close[[
        'date', 'exe_date', 'weekday', 'neutral_pnl', 'ret', 'dtm'
    ]],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))

# %%
def categorize(df, seperators, target_column, column_name):
    all_temps = []
    for k in range(len(seperators)):
        if k == 0:
            temp = df[df[target_column] <= seperators[0]][:]
        else:
            temp = df[(df[target_column] > seperators[k - 1])
                      & (df[target_column] <= seperators[k])][:]
        temp[column_name] = k

        all_temps.append(temp)
    temp = df[(df[target_column] > seperators[-1])][:]
    temp[column_name] = len(seperators)
    all_temps.append(temp)
    return pd.concat(all_temps).reset_index(drop=True)


def RV_OLS(df, method='neutral_pnl', add=False):
    df = df.dropna()
    y = df[method].values
    X = np.column_stack([
        df['rv_level'].apply(lambda x: 1 if x == i else 0) for i in range(10)
    ])
    model = sm.OLS(y, X)
    model = model.fit()
    for j, k in enumerate(model.params):
        print(round(k, 4))
        print("({})".format(round(model.tvalues[j], 2)))


#     print(round(model.f_pvalue, 4))
    print(round(model.rsquared_adj, 4))
    print(model.summary())
    return model

# %% [markdown]
# ## 到期日与实现波动率的关系？

# %%
new_straddles = pd.read_csv('all_straddles_cd.csv')

# %%
straddle_rv = pd.merge(
    close_to_close[[
        'date', 'exe_date', 'weekday', 'neutral_pnl', 'ret', 'dtm'
    ]],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.rv.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)
# Out:
# -0.0248
# (-6.54)
# -0.0177
# (-4.66)
# -0.0173
# (-4.52)
# -0.0144
# (-3.77)
# 0.0001
# (0.02)
# -0.0028
# (-0.74)
# 0.0006
# (0.15)
# 0.0119
# (3.13)
# 0.0088
# (2.31)
# 0.0454
# (11.87)
# 0.0581
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     28.34
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           3.51e-48
# Time:                        22:20:16   Log-Likelihood:                 4621.3
# No. Observations:                3989   AIC:                            -9223.
# Df Residuals:                    3979   BIC:                            -9160.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0248      0.004     -6.542      0.000      -0.032      -0.017
# x2            -0.0177      0.004     -4.657      0.000      -0.025      -0.010
# x3            -0.0173      0.004     -4.520      0.000      -0.025      -0.010
# x4            -0.0144      0.004     -3.772      0.000      -0.022      -0.007
# x5          8.409e-05      0.004      0.022      0.982      -0.007       0.008
# x6            -0.0028      0.004     -0.740      0.459      -0.010       0.005
# x7             0.0006      0.004      0.148      0.883      -0.007       0.008
# x8             0.0119      0.004      3.131      0.002       0.004       0.019
# x9             0.0088      0.004      2.311      0.021       0.001       0.016
# x10            0.0454      0.004     11.873      0.000       0.038       0.053
# ==============================================================================
# Omnibus:                     4826.046   Durbin-Watson:                   0.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1489186.014
# Skew:                           6.072   Prob(JB):                         0.00
# Kurtosis:                      96.874   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
straddle_rv = pd.merge(
    close_to_close[[
        'date', 'exe_date', 'weekday', 'neutral_pnl', 'ret', 'dtm'
    ]],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.rv.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

straddle_rv = pd.merge(
    close_to_open[['date', 'exe_date', 'weekday', 'neutral_pnl', 'ret',
                   'dtm']],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.rv.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

straddle_rv = pd.merge(
    open_to_close[['date', 'exe_date', 'weekday', 'neutral_pnl', 'ret',
                   'dtm']],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.id_rv.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)
# Out:
# -0.0248
# (-6.54)
# -0.0177
# (-4.66)
# -0.0173
# (-4.52)
# -0.0144
# (-3.77)
# 0.0001
# (0.02)
# -0.0028
# (-0.74)
# 0.0006
# (0.15)
# 0.0119
# (3.13)
# 0.0088
# (2.31)
# 0.0454
# (11.87)
# 0.0581
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     28.34
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           3.51e-48
# Time:                        22:20:17   Log-Likelihood:                 4621.3
# No. Observations:                3989   AIC:                            -9223.
# Df Residuals:                    3979   BIC:                            -9160.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0248      0.004     -6.542      0.000      -0.032      -0.017
# x2            -0.0177      0.004     -4.657      0.000      -0.025      -0.010
# x3            -0.0173      0.004     -4.520      0.000      -0.025      -0.010
# x4            -0.0144      0.004     -3.772      0.000      -0.022      -0.007
# x5          8.409e-05      0.004      0.022      0.982      -0.007       0.008
# x6            -0.0028      0.004     -0.740      0.459      -0.010       0.005
# x7             0.0006      0.004      0.148      0.883      -0.007       0.008
# x8             0.0119      0.004      3.131      0.002       0.004       0.019
# x9             0.0088      0.004      2.311      0.021       0.001       0.016
# x10            0.0454      0.004     11.873      0.000       0.038       0.053
# ==============================================================================
# Omnibus:                     4826.046   Durbin-Watson:                   0.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1489186.014
# Skew:                           6.072   Prob(JB):                         0.00
# Kurtosis:                      96.874   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0017
# (-1.34)
# -0.0017
# (-1.26)
# -0.0009
# (-0.66)
# -0.0029
# (-2.19)
# -0.0015
# (-1.18)
# 0.0
# (0.03)
# -0.0001
# (-0.08)
# -0.0005
# (-0.4)
# 0.0005
# (0.37)
# 0.0127
# (9.67)
# 0.023
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     11.44
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           7.10e-18
# Time:                        22:20:17   Log-Likelihood:                 8878.6
# No. Observations:                3989   AIC:                        -1.774e+04
# Df Residuals:                    3979   BIC:                        -1.767e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0017      0.001     -1.338      0.181      -0.004       0.001
# x2            -0.0017      0.001     -1.263      0.207      -0.004       0.001
# x3            -0.0009      0.001     -0.660      0.509      -0.003       0.002
# x4            -0.0029      0.001     -2.185      0.029      -0.005      -0.000
# x5            -0.0015      0.001     -1.180      0.238      -0.004       0.001
# x6          4.193e-05      0.001      0.032      0.975      -0.003       0.003
# x7            -0.0001      0.001     -0.077      0.939      -0.003       0.002
# x8            -0.0005      0.001     -0.404      0.686      -0.003       0.002
# x9             0.0005      0.001      0.367      0.714      -0.002       0.003
# x10            0.0127      0.001      9.669      0.000       0.010       0.015
# ==============================================================================
# Omnibus:                     5926.539   Durbin-Watson:                   1.669
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7412026.344
# Skew:                           8.505   Prob(JB):                         0.00
# Kurtosis:                     213.489   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0231
# (-5.57)
# -0.0186
# (-4.55)
# -0.0162
# (-4.46)
# -0.0152
# (-3.88)
# -0.0068
# (-1.85)
# 0.0007
# (0.18)
# -0.0019
# (-0.52)
# -0.0007
# (-0.2)
# 0.019
# (5.75)
# 0.0204
# (7.11)
# 0.0394
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     19.16
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           1.02e-31
# Time:                        22:20:17   Log-Likelihood:                 4862.4
# No. Observations:                3989   AIC:                            -9705.
# Df Residuals:                    3979   BIC:                            -9642.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0231      0.004     -5.574      0.000      -0.031      -0.015
# x2            -0.0186      0.004     -4.550      0.000      -0.027      -0.011
# x3            -0.0162      0.004     -4.463      0.000      -0.023      -0.009
# x4            -0.0152      0.004     -3.877      0.000      -0.023      -0.008
# x5            -0.0068      0.004     -1.852      0.064      -0.014       0.000
# x6             0.0007      0.004      0.178      0.859      -0.007       0.008
# x7            -0.0019      0.004     -0.518      0.604      -0.009       0.005
# x8            -0.0007      0.003     -0.200      0.842      -0.007       0.006
# x9             0.0190      0.003      5.746      0.000       0.013       0.026
# x10            0.0204      0.003      7.110      0.000       0.015       0.026
# ==============================================================================
# Omnibus:                     4621.865   Durbin-Watson:                   0.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1269099.792
# Skew:                           5.631   Prob(JB):                         0.00
# Kurtosis:                      89.653   Cond. No.                         1.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Result Analysis: A basic case.
model = sm.OLS(rv_df.neutral_pnl.values, sm.add_constant(rv_df.rv.values))
model = model.fit()
print(model.summary())


def delta_OLS_effect(df, test_col, add=False):
    df = df.dropna()
    MON = (df['weekday'].apply(lambda x: 1 if x == 0 else 0) *
           df[test_col]).values
    TUE = (df['weekday'].apply(lambda x: 1 if x == 1 else 0) *
           df[test_col]).values
    WED = (df['weekday'].apply(lambda x: 1 if x == 2 else 0) *
           df[test_col]).values
    THU = (df['weekday'].apply(lambda x: 1 if x == 3 else 0) *
           df[test_col]).values
    FRI = (df['weekday'].apply(lambda x: 1 if x == 4 else 0) *
           df[test_col]).values
    y = df.neutral_pnl.values
    X = np.column_stack([MON, TUE, WED, THU, FRI])
    if add:
        X = sm.add_constant(X)
    model = sm.OLS(y, X)
    model = model.fit()
    for j, k in enumerate(model.params):
        print(round(k, 4))
        print("({})".format(round(model.tvalues[j], 2)))


#     print(round(model.f_pvalue, 4))
    print(round(model.rsquared_adj, 4))
    print(model.summary())
    return model

delta_OLS_effect(rv_df[rv_df['dtm'] >= 63], 'rvc')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     362.7
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           1.82e-77
# Time:                        22:20:17   Log-Likelihood:                 4951.5
# No. Observations:                3989   AIC:                            -9899.
# Df Residuals:                    3987   BIC:                            -9886.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0402      0.002    -17.354      0.000      -0.045      -0.036
# x1             0.2477      0.013     19.045      0.000       0.222       0.273
# ==============================================================================
# Omnibus:                     4299.670   Durbin-Watson:                   0.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1078291.330
# Skew:                           4.943   Prob(JB):                         0.00
# Kurtosis:                      82.937   Cond. No.                         12.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.1928
# (7.73)
# 0.1255
# (5.67)
# 0.0661
# (1.91)
# 0.1946
# (5.18)
# 0.3698
# (19.8)
# 0.1886
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.190
# Model:                            OLS   Adj. R-squared (uncentered):              0.189
# Method:                 Least Squares   F-statistic:                              102.9
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):                    1.01e-97
# Time:                        22:20:17   Log-Likelihood:                          3538.5
# No. Observations:                2192   AIC:                                     -7067.
# Df Residuals:                    2187   BIC:                                     -7039.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1928      0.025      7.732      0.000       0.144       0.242
# x2             0.1255      0.022      5.669      0.000       0.082       0.169
# x3             0.0661      0.035      1.913      0.056      -0.002       0.134
# x4             0.1946      0.038      5.180      0.000       0.121       0.268
# x5             0.3698      0.019     19.804      0.000       0.333       0.406
# ==============================================================================
# Omnibus:                     1798.257   Durbin-Watson:                   1.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           105961.136
# Skew:                           3.439   Prob(JB):                         0.00
# Kurtosis:                      36.359   Cond. No.                         2.01
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
rv_df[(rv_df['rv'] <= rv_division[1]) & (rv_df['weekday'] == 0)].shape
# Out:
# (98, 15)

# %% [markdown]
# ## 其他delta-neutral

# %%
daily = pd.read_csv('daily_underlying.csv')
daily.columns = ['date', 'underlying']

long_call = pd.DataFrame()
for fn in os.listdir('new_cd/call'):
    path = 'new_cd/call/' + fn
    tmp = pd.read_csv(path)
    tmp = pd.merge(tmp[tmp['dtm'] >= 6], daily, on='date')
    tmp['imp_und'] = tmp.stock_price
    tmp['und_diff'] = tmp['underlying'] - tmp['imp_und']
    tmp['stock_pnl'] = tmp.imp_und - tmp.imp_und.shift(1)
    tmp['last_delta'] = tmp.call_delta.shift(1)
    tmp['option_ret'] = (tmp.next_close - tmp.call_close).shift(1)
    tmp['cost'] = tmp.call_close.shift(1)
    tmp['neutral_pnl'] = (-tmp.last_delta * tmp.stock_pnl +
                          tmp.option_ret) / (tmp.cost)
    long_call = pd.concat([
        long_call, tmp[['date', 'dtm', 'weekday', 'neutral_pnl',
                        'und_diff']].dropna(how='any')
    ])
    long_call = long_call[long_call['date'] >= '2016-11-01']
long_put = pd.DataFrame()
for fn in os.listdir('new_cd/put'):
    path = 'new_cd/put/' + fn
    tmp = pd.read_csv(path)
    tmp = pd.merge(tmp[tmp['dtm'] >= 6], daily, on='date')
    tmp['imp_und'] = tmp.stock_price
    tmp['und_diff'] = tmp['underlying'] - tmp['imp_und']
    tmp['stock_pnl'] = tmp.underlying - tmp.underlying.shift(1)
    tmp['last_delta'] = tmp.put_delta.shift(1)
    tmp['option_ret'] = (tmp.next_close - tmp.put_close).shift(1)
    tmp['cost'] = tmp.put_close.shift(1)
    tmp['neutral_pnl'] = (-tmp.last_delta * tmp.stock_pnl +
                          tmp.option_ret) / (tmp.cost)
    long_put = pd.concat([
        long_put, tmp[['date', 'dtm', 'weekday', 'neutral_pnl',
                       'und_diff']].dropna(how='any')
    ])
    long_put = long_put[long_put['date'] >= '2016-11-01']

# %%
lc_rv = pd.merge(
    long_call[['date', 'weekday', 'neutral_pnl']],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))

rv_division = [np.percentile(lc_rv.rvc.values, 10 * j) for j in range(1, 10)]
rv_df = categorize(lc_rv, rv_division, 'rvc', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

rv_division = [np.percentile(lc_rv.id_rv.values, 10 * j) for j in range(1, 10)]
rv_df = categorize(lc_rv, rv_division, 'id_rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

rv_division = [np.percentile(lc_rv.on_rv.values, 10 * j) for j in range(1, 10)]
rv_df = categorize(lc_rv, rv_division, 'on_rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)
# Out:
# 0.0222
# (5.09)
# -0.0013
# (-0.29)
# 0.0124
# (2.85)
# -0.0125
# (-2.86)
# -0.008
# (-1.83)
# -0.0162
# (-3.72)
# -0.0091
# (-2.09)
# -0.012
# (-2.77)
# -0.0009
# (-0.21)
# 0.0004
# (0.1)
# 0.0146
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     7.586
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           4.19e-11
# Time:                        22:20:53   Log-Likelihood:                 4084.3
# No. Observations:                4000   AIC:                            -8149.
# Df Residuals:                    3990   BIC:                            -8086.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0222      0.004      5.087      0.000       0.014       0.031
# x2            -0.0013      0.004     -0.291      0.771      -0.010       0.007
# x3             0.0124      0.004      2.851      0.004       0.004       0.021
# x4            -0.0125      0.004     -2.858      0.004      -0.021      -0.004
# x5            -0.0080      0.004     -1.832      0.067      -0.017       0.001
# x6            -0.0162      0.004     -3.721      0.000      -0.025      -0.008
# x7            -0.0091      0.004     -2.093      0.036      -0.018      -0.001
# x8            -0.0120      0.004     -2.765      0.006      -0.021      -0.004
# x9            -0.0009      0.004     -0.214      0.831      -0.010       0.008
# x10            0.0004      0.004      0.102      0.919      -0.008       0.009
# ==============================================================================
# Omnibus:                     4682.130   Durbin-Watson:                   1.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1308716.206
# Skew:                           5.735   Prob(JB):                         0.00
# Kurtosis:                      90.868   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0212
# (-4.94)
# -0.0137
# (-3.19)
# -0.0084
# (-1.97)
# -0.014
# (-3.26)
# -0.0021
# (-0.48)
# -0.0072
# (-1.67)
# -0.0077
# (-1.78)
# -0.01
# (-2.33)
# 0.0118
# (2.75)
# 0.0479
# (11.11)
# 0.0429
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     20.91
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           7.16e-35
# Time:                        22:20:53   Log-Likelihood:                 4142.5
# No. Observations:                4000   AIC:                            -8265.
# Df Residuals:                    3990   BIC:                            -8202.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0212      0.004     -4.940      0.000      -0.030      -0.013
# x2            -0.0137      0.004     -3.188      0.001      -0.022      -0.005
# x3            -0.0084      0.004     -1.967      0.049      -0.017   -2.55e-05
# x4            -0.0140      0.004     -3.261      0.001      -0.022      -0.006
# x5            -0.0021      0.004     -0.480      0.631      -0.011       0.006
# x6            -0.0072      0.004     -1.669      0.095      -0.016       0.001
# x7            -0.0077      0.004     -1.784      0.074      -0.016       0.001
# x8            -0.0100      0.004     -2.330      0.020      -0.018      -0.002
# x9             0.0118      0.004      2.749      0.006       0.003       0.020
# x10            0.0479      0.004     11.105      0.000       0.039       0.056
# ==============================================================================
# Omnibus:                     4591.895   Durbin-Watson:                   1.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1198453.127
# Skew:                           5.553   Prob(JB):                         0.00
# Kurtosis:                      87.068   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0158
# (-3.67)
# -0.0185
# (-4.27)
# -0.0188
# (-4.37)
# -0.003
# (-0.7)
# 0.0017
# (0.4)
# 0.0043
# (1.0)
# -0.0027
# (-0.63)
# -0.0077
# (-1.8)
# -0.0063
# (-1.46)
# 0.0422
# (9.76)
# 0.0341
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     16.68
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           2.94e-27
# Time:                        22:20:53   Log-Likelihood:                 4124.2
# No. Observations:                4000   AIC:                            -8228.
# Df Residuals:                    3990   BIC:                            -8165.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0158      0.004     -3.671      0.000      -0.024      -0.007
# x2            -0.0185      0.004     -4.271      0.000      -0.027      -0.010
# x3            -0.0188      0.004     -4.372      0.000      -0.027      -0.010
# x4            -0.0030      0.004     -0.701      0.483      -0.011       0.005
# x5             0.0017      0.004      0.397      0.691      -0.007       0.010
# x6             0.0043      0.004      0.998      0.318      -0.004       0.013
# x7            -0.0027      0.004     -0.630      0.529      -0.011       0.006
# x8            -0.0077      0.004     -1.798      0.072      -0.016       0.001
# x9            -0.0063      0.004     -1.455      0.146      -0.015       0.002
# x10            0.0422      0.004      9.758      0.000       0.034       0.051
# ==============================================================================
# Omnibus:                     4546.145   Durbin-Watson:                   1.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1174960.324
# Skew:                           5.452   Prob(JB):                         0.00
# Kurtosis:                      86.252   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lp_rv = pd.merge(
    long_put[['date', 'weekday', 'neutral_pnl']],
    pd.DataFrame({
        'date': rvs.date[1:].values,
        'rv': rvs.rv[1:].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values
    }))

rv_division = [np.percentile(lp_rv.rv.values, 10 * j) for j in range(1, 10)]
rv_df = categorize(lp_rv, rv_division, 'rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

rv_division = [np.percentile(lp_rv.id_rv.values, 10 * j) for j in range(1, 10)]
rv_df = categorize(lp_rv, rv_division, 'id_rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

rv_division = [np.percentile(lp_rv.on_rv.values, 10 * j) for j in range(1, 10)]
rv_df = categorize(lp_rv, rv_division, 'on_rv', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)
# Out:
# -0.0293
# (-5.6)
# -0.0224
# (-4.26)
# -0.0154
# (-2.94)
# -0.0125
# (-2.39)
# 0.0019
# (0.36)
# -0.001
# (-0.18)
# 0.0052
# (0.98)
# 0.014
# (2.65)
# 0.0124
# (2.35)
# 0.0485
# (9.25)
# 0.0371
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     18.11
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           7.77e-30
# Time:                        22:20:53   Log-Likelihood:                 3348.6
# No. Observations:                4000   AIC:                            -6677.
# Df Residuals:                    3990   BIC:                            -6614.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0293      0.005     -5.595      0.000      -0.040      -0.019
# x2            -0.0224      0.005     -4.258      0.000      -0.033      -0.012
# x3            -0.0154      0.005     -2.937      0.003      -0.026      -0.005
# x4            -0.0125      0.005     -2.387      0.017      -0.023      -0.002
# x5             0.0019      0.005      0.359      0.719      -0.008       0.012
# x6            -0.0010      0.005     -0.182      0.855      -0.011       0.009
# x7             0.0052      0.005      0.984      0.325      -0.005       0.015
# x8             0.0140      0.005      2.650      0.008       0.004       0.024
# x9             0.0124      0.005      2.355      0.019       0.002       0.023
# x10            0.0485      0.005      9.250      0.000       0.038       0.059
# ==============================================================================
# Omnibus:                     4567.896   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1099690.782
# Skew:                           5.531   Prob(JB):                         0.00
# Kurtosis:                      83.472   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0286
# (-5.47)
# -0.0285
# (-5.44)
# -0.0124
# (-2.36)
# -0.0152
# (-2.9)
# 0.0062
# (1.18)
# 0.0
# (0.0)
# 0.0033
# (0.63)
# 0.0063
# (1.2)
# 0.0255
# (4.87)
# 0.045
# (8.56)
# 0.0396
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     19.31
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           5.39e-32
# Time:                        22:20:53   Log-Likelihood:                 3353.8
# No. Observations:                4000   AIC:                            -6688.
# Df Residuals:                    3990   BIC:                            -6625.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0286      0.005     -5.472      0.000      -0.039      -0.018
# x2            -0.0285      0.005     -5.442      0.000      -0.039      -0.018
# x3            -0.0124      0.005     -2.364      0.018      -0.023      -0.002
# x4            -0.0152      0.005     -2.901      0.004      -0.025      -0.005
# x5             0.0062      0.005      1.182      0.237      -0.004       0.017
# x6          2.277e-06      0.005      0.000      1.000      -0.010       0.010
# x7             0.0033      0.005      0.626      0.531      -0.007       0.014
# x8             0.0063      0.005      1.203      0.229      -0.004       0.017
# x9             0.0255      0.005      4.871      0.000       0.015       0.036
# x10            0.0450      0.005      8.561      0.000       0.035       0.055
# ==============================================================================
# Omnibus:                     4587.198   Durbin-Watson:                   1.404
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1097396.959
# Skew:                           5.578   Prob(JB):                         0.00
# Kurtosis:                      83.374   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0018
# (0.34)
# 0.0056
# (1.05)
# 0.0003
# (0.05)
# -0.0053
# (-0.99)
# -0.0008
# (-0.15)
# -0.0009
# (-0.16)
# -0.0072
# (-1.36)
# -0.0009
# (-0.18)
# 0.0013
# (0.24)
# 0.0074
# (1.37)
# -0.0007
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6700
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):              0.737
# Time:                        22:20:53   Log-Likelihood:                 3271.5
# No. Observations:                4000   AIC:                            -6523.
# Df Residuals:                    3990   BIC:                            -6460.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0018      0.005      0.335      0.737      -0.009       0.012
# x2             0.0056      0.005      1.047      0.295      -0.005       0.016
# x3             0.0003      0.005      0.052      0.959      -0.010       0.011
# x4            -0.0053      0.005     -0.986      0.324      -0.016       0.005
# x5            -0.0008      0.005     -0.153      0.879      -0.011       0.010
# x6            -0.0009      0.005     -0.159      0.874      -0.011       0.010
# x7            -0.0072      0.005     -1.355      0.175      -0.018       0.003
# x8            -0.0009      0.005     -0.176      0.860      -0.011       0.010
# x9             0.0013      0.005      0.243      0.808      -0.009       0.012
# x10            0.0074      0.005      1.370      0.171      -0.003       0.018
# ==============================================================================
# Omnibus:                     4616.902   Durbin-Watson:                   1.364
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1077520.621
# Skew:                           5.657   Prob(JB):                         0.00
# Kurtosis:                      82.606   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 实现波动率变化与straddle return

# %%
rv_division = [
    np.percentile(straddle_rv.abs_rvc.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'abs_rvc', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df, 'ret')
# Out:
# -0.0019
# (-1.37)
# -0.0023
# (-1.64)
# -0.0032
# (-2.24)
# -0.0026
# (-1.86)
# 0.0001
# (0.08)
# -0.0007
# (-0.49)
# -0.0031
# (-2.19)
# 0.0028
# (1.99)
# -0.0017
# (-1.21)
# 0.0109
# (7.61)
# 0.0178
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     9.028
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           1.28e-13
# Time:                        22:20:53   Log-Likelihood:                 8549.3
# No. Observations:                3989   AIC:                        -1.708e+04
# Df Residuals:                    3979   BIC:                        -1.702e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0019      0.001     -1.370      0.171      -0.005       0.001
# x2            -0.0023      0.001     -1.636      0.102      -0.005       0.000
# x3            -0.0032      0.001     -2.240      0.025      -0.006      -0.000
# x4            -0.0026      0.001     -1.862      0.063      -0.005       0.000
# x5             0.0001      0.001      0.079      0.937      -0.003       0.003
# x6            -0.0007      0.001     -0.492      0.623      -0.003       0.002
# x7            -0.0031      0.001     -2.190      0.029      -0.006      -0.000
# x8             0.0028      0.001      1.994      0.046    4.81e-05       0.006
# x9            -0.0017      0.001     -1.207      0.228      -0.004       0.001
# x10            0.0109      0.001      7.611      0.000       0.008       0.014
# ==============================================================================
# Omnibus:                     4066.715   Durbin-Watson:                   0.779
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           595726.588
# Skew:                           4.660   Prob(JB):                         0.00
# Kurtosis:                      62.138   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def leveled_analysis(df, target_col):
    rv_division = [
        np.percentile(df[target_col].values, 10 * j) for j in range(1, 10)
    ]
    rv_df = categorize(df, rv_division, target_col, 'rv_level')
    rv_df.sort_values(by='date').reset_index(drop=True)
    print('Percentiles: ', rv_division)
    RV_OLS(rv_df)


leveled_analysis(straddle_rv, 'rvc')
# Out:
# Percentiles:  [-0.0716538020686379, -0.04029479547403833, -0.021582989192098542, -0.010086572710607145, -0.0015489531344572982, 0.010400800387845924, 0.02247688754458008, 0.040311917795589645, 0.06784614059471956]
# -0.0184
# (-5.18)
# -0.0073
# (-2.06)
# -0.0123
# (-3.43)
# -0.013
# (-3.66)
# -0.0158
# (-4.45)
# -0.0034
# (-0.97)
# -0.0023
# (-0.65)
# 0.0031
# (0.87)
# 0.0104
# (2.92)
# 0.0446
# (12.55)
# 0.0553
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     26.95
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           1.04e-45
# Time:                        22:20:53   Log-Likelihood:                 4895.9
# No. Observations:                3989   AIC:                            -9772.
# Df Residuals:                    3979   BIC:                            -9709.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0184      0.004     -5.176      0.000      -0.025      -0.011
# x2            -0.0073      0.004     -2.063      0.039      -0.014      -0.000
# x3            -0.0123      0.004     -3.435      0.001      -0.019      -0.005
# x4            -0.0130      0.004     -3.661      0.000      -0.020      -0.006
# x5            -0.0158      0.004     -4.451      0.000      -0.023      -0.009
# x6            -0.0034      0.004     -0.967      0.334      -0.010       0.004
# x7            -0.0023      0.004     -0.646      0.518      -0.009       0.005
# x8             0.0031      0.004      0.868      0.386      -0.004       0.010
# x9             0.0104      0.004      2.915      0.004       0.003       0.017
# x10            0.0446      0.004     12.553      0.000       0.038       0.052
# ==============================================================================
# Omnibus:                     4484.030   Durbin-Watson:                   0.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1152458.677
# Skew:                           5.341   Prob(JB):                         0.00
# Kurtosis:                      85.582   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
straddle_rv = pd.merge(
    close_to_close[[
        'date', 'exe_date', 'weekday', 'neutral_pnl', 'ret', 'dtm'
    ]],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.rvc.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rvc', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

straddle_rv = pd.merge(
    close_to_open[['date', 'exe_date', 'weekday', 'neutral_pnl', 'ret',
                   'dtm']],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.rvc.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rvc', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)

straddle_rv = pd.merge(
    open_to_close[['date', 'exe_date', 'weekday', 'neutral_pnl', 'ret',
                   'dtm']],
    pd.DataFrame({
        'date': rvs.date[:-1].values,
        'rv': rvs.rv[1:].values,
        'abs_rvc': rvs.abs_rvc[1:].values,
        'rvc': rvs.rvc[1:].values,
        'rvc_id': rvs.rvc_id[1:].values,
        'rvc_on': rvs.rvc_on[:-1].values,
        'id_rv': rvs.id_rv[1:].values,
        'on_rv': rvs.on_rv[:-1].values,
        'pct_rvc': rvs.pct_rvc[:-1].values
    }))
rv_division = [
    np.percentile(straddle_rv.rvc.values, 10 * j) for j in range(1, 10)
]
rv_df = categorize(straddle_rv, rv_division, 'rvc', 'rv_level')
rv_df.sort_values(by='date').reset_index(drop=True)
RV_OLS(rv_df)
# Out:
# -0.0241
# (-6.4)
# -0.0104
# (-2.77)
# -0.0121
# (-3.19)
# -0.0141
# (-3.75)
# -0.0164
# (-4.34)
# -0.0039
# (-1.03)
# -0.0033
# (-0.86)
# 0.0032
# (0.84)
# 0.0115
# (3.05)
# 0.0589
# (15.64)
# 0.0782
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     38.58
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           2.34e-66
# Time:                        22:14:14   Log-Likelihood:                 4664.5
# No. Observations:                3989   AIC:                            -9309.
# Df Residuals:                    3979   BIC:                            -9246.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0241      0.004     -6.396      0.000      -0.031      -0.017
# x2            -0.0104      0.004     -2.767      0.006      -0.018      -0.003
# x3            -0.0121      0.004     -3.195      0.001      -0.019      -0.005
# x4            -0.0141      0.004     -3.751      0.000      -0.021      -0.007
# x5            -0.0164      0.004     -4.343      0.000      -0.024      -0.009
# x6            -0.0039      0.004     -1.026      0.305      -0.011       0.004
# x7            -0.0033      0.004     -0.863      0.388      -0.011       0.004
# x8             0.0032      0.004      0.836      0.403      -0.004       0.011
# x9             0.0115      0.004      3.050      0.002       0.004       0.019
# x10            0.0589      0.004     15.637      0.000       0.052       0.066
# ==============================================================================
# Omnibus:                     4795.394   Durbin-Watson:                   0.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1473552.997
# Skew:                           5.998   Prob(JB):                         0.00
# Kurtosis:                      96.390   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0057
# (-4.37)
# -0.0031
# (-2.37)
# 0.0002
# (0.13)
# -0.0011
# (-0.86)
# -0.0005
# (-0.41)
# -0.0004
# (-0.33)
# -0.001
# (-0.74)
# 0.0001
# (0.05)
# 0.0011
# (0.86)
# 0.0143
# (10.97)
# 0.0333
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     16.27
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           1.60e-26
# Time:                        22:14:14   Log-Likelihood:                 8900.2
# No. Observations:                3989   AIC:                        -1.778e+04
# Df Residuals:                    3979   BIC:                        -1.772e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0057      0.001     -4.371      0.000      -0.008      -0.003
# x2            -0.0031      0.001     -2.370      0.018      -0.006      -0.001
# x3             0.0002      0.001      0.133      0.894      -0.002       0.003
# x4            -0.0011      0.001     -0.856      0.392      -0.004       0.001
# x5            -0.0005      0.001     -0.410      0.682      -0.003       0.002
# x6            -0.0004      0.001     -0.327      0.744      -0.003       0.002
# x7            -0.0010      0.001     -0.735      0.462      -0.004       0.002
# x8           6.94e-05      0.001      0.053      0.958      -0.002       0.003
# x9             0.0011      0.001      0.865      0.387      -0.001       0.004
# x10            0.0143      0.001     10.966      0.000       0.012       0.017
# ==============================================================================
# Omnibus:                     5948.527   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7590161.373
# Skew:                           8.564   Prob(JB):                         0.00
# Kurtosis:                     216.010   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0184
# (-5.18)
# -0.0073
# (-2.06)
# -0.0123
# (-3.43)
# -0.013
# (-3.66)
# -0.0158
# (-4.45)
# -0.0034
# (-0.97)
# -0.0023
# (-0.65)
# 0.0031
# (0.87)
# 0.0104
# (2.92)
# 0.0446
# (12.55)
# 0.0553
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     26.95
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):           1.05e-45
# Time:                        22:14:14   Log-Likelihood:                 4895.9
# No. Observations:                3989   AIC:                            -9772.
# Df Residuals:                    3979   BIC:                            -9709.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0184      0.004     -5.176      0.000      -0.025      -0.011
# x2            -0.0073      0.004     -2.064      0.039      -0.014      -0.000
# x3            -0.0123      0.004     -3.434      0.001      -0.019      -0.005
# x4            -0.0130      0.004     -3.661      0.000      -0.020      -0.006
# x5            -0.0158      0.004     -4.452      0.000      -0.023      -0.009
# x6            -0.0034      0.004     -0.967      0.334      -0.010       0.004
# x7            -0.0023      0.004     -0.645      0.519      -0.009       0.005
# x8             0.0031      0.004      0.867      0.386      -0.004       0.010
# x9             0.0104      0.004      2.916      0.004       0.003       0.017
# x10            0.0446      0.004     12.552      0.000       0.038       0.052
# ==============================================================================
# Omnibus:                     4484.284   Durbin-Watson:                   0.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1152746.654
# Skew:                           5.341   Prob(JB):                         0.00
# Kurtosis:                      85.592   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
